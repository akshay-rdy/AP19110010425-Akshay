# %% [markdown]
# # Task Day-14(23-06-21)
#
# Getting and knowing your Data
#
# There are many kinds of birds: pigeons, ducks, ostriches, penguins… Some are good at flying, others can't fly but run fast. Some swim under water, others wading in shallow pool.
#
# According to their living environments and living habits, birds are classified into different ecological groups. There are 6 ecological groups of birds:
#
# 1) Swimming Birds
#
# 2) Wading Birds
#
# 3) Terrestrial Birds
#
# 4) Raptors
#
# 5) Scansorial Birds
#
# 6) Singing Birds

# %%
import pandas as pd

# %%
birds = pd.read_csv(r"C:\Users\Akshay\OneDrive\Desktop\info\archive\bird.csv")
birds
# Out:
#       id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# 0      0   80.78   6.68   72.01   4.88  41.81  3.70    5.50  4.03  38.70
# 1      1   88.91   6.63   80.53   5.59  47.04  4.30   80.22  4.51  41.50
# 2      2   79.97   6.37   69.26   5.28  43.07  3.90   75.35  4.04  38.31
# 3      3   77.65   5.70   65.76   4.77  40.04  3.52   69.17  3.40  35.78
# 4      4   62.80   4.84   52.09   3.73  33.95  2.72   56.27  2.96  31.88
# 5      5   61.92   4.78   50.46   3.47  49.52  4.41   56.95  2.73  29.07
# 6      6   79.73   5.94   67.39   4.50  42.07  3.41   71.26  3.56  37.22
# 7      7   86.98   5.68   74.52   4.55  44.46  3.78   76.02  3.81  37.94
# 8      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# 9      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# 10    10  165.00  11.45  156.00   8.68  80.25  7.85  143.00  8.25  86.61
# 11    11  186.00   9.83  152.00   8.76  56.02  7.02  185.00  8.07  90.80
# ...

# %% [markdown]
# ## See the random 5 entries

# %%
birds.sample(5)
# Out:
#       id    huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  tarw  \
# 88    88   80.70  5.23   85.96   4.25  32.80  2.98   70.57  2.88  39.77  2.38
# 230  230   41.65  3.62   46.01   3.03  38.37  2.85   48.11  2.55  35.49  2.22
# 237  237  119.12  7.57  137.37   6.06  75.53  6.35  115.02  6.22  60.99  7.91
# 164  164   85.00  5.07   93.17   4.21  38.33  2.57   67.32  2.73  40.00  2.53
# 361  361   20.08  2.07   25.78   1.81  20.43  1.62   38.30  1.35  30.25  1.09
#
#     type
# 88    SW
# 230    R
# 237    R
# 164    W
# 361   SO

# %% [markdown]
# ## What is the number of observations in the dataset

# %%
print(birds.shape[0])
# Out:
# 420

# %% [markdown]
# ## What is the number of columns in the dataset?

# %%
print(len(birds.columns))
# Out:
# 12

# %% [markdown]
# ##  Print the name of all the columns.

# %%
for x in birds.columns:
    print(x)
# Out:
# id
# huml
# humw
# ulnal
# ulnaw
# feml
# femw
# tibl
# tibw
# tarl
# tarw
# type

# %% [markdown]
# ## What is the name of 10th column?

# %%
print(birds.columns[9])
# Out:
# tarl

# %% [markdown]
# ## What is the type of the observations of the 2th column?

# %%
print(type(birds[birds.columns[1]]))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ## How is the dataset indexed?

# %%
print(birds.index)
# Out:
# RangeIndex(start=0, stop=420, step=1)

# %% [markdown]
# ## Set the 'type' colum as the index of the dataframe

# %%
birds.set_index("type", inplace = True)
birds
# Out:
#        id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# type
# SW      0   80.78   6.68   72.01   4.88  41.81  3.70    5.50  4.03  38.70
# SW      1   88.91   6.63   80.53   5.59  47.04  4.30   80.22  4.51  41.50
# SW      2   79.97   6.37   69.26   5.28  43.07  3.90   75.35  4.04  38.31
# SW      3   77.65   5.70   65.76   4.77  40.04  3.52   69.17  3.40  35.78
# SW      4   62.80   4.84   52.09   3.73  33.95  2.72   56.27  2.96  31.88
# SW      5   61.92   4.78   50.46   3.47  49.52  4.41   56.95  2.73  29.07
# SW      6   79.73   5.94   67.39   4.50  42.07  3.41   71.26  3.56  37.22
# SW      7   86.98   5.68   74.52   4.55  44.46  3.78   76.02  3.81  37.94
# SW      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# SW      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# SW     10  165.00  11.45  156.00   8.68  80.25  7.85  143.00  8.25  86.61
# SW     11  186.00   9.83  152.00   8.76  56.02  7.02  185.00  8.07  90.80
# ...

# %% [markdown]
# ## Print only the column huml

# %%
birds["huml"]
# Out:
# type
# SW     80.78
# SW     88.91
# SW     79.97
# SW     77.65
# SW     62.80
# SW     61.92
# SW     79.73
# SW     86.98
# SW    118.20
# SW    145.00
# SW    165.00
# SW    186.00
# SW    172.00
# SW    148.91
# SW    149.19
# SW    140.59
# SW    135.23
# SW    124.53
# SW    127.03
# SW    106.02
# SW    113.84
# SW    108.62
# SW    110.33
# SW     63.62
# SW     70.73
# SW     71.65
# SW     47.51
# SW     46.20
# SW     41.13
# SW     72.50
#        ...
# SO     20.43
# SO     22.19
# SO     23.27
# SO     18.97
# SO     15.99
# SO     15.62
# SO     16.51
# SO     16.80
# SO     15.55
# SO     23.32
# SO     20.41
# SO     21.53
# SO     22.84
# SO     20.95
# SO     20.36
# SO     17.30
# SO     16.86
# SO     15.70
# SO     19.54
# SO     23.27
# SO     23.04
# SO     21.21
# SO     21.92
# SO     12.95
# SO     13.63
# SO     17.96
# SO     19.21
# SO     18.79
# SO     20.38
# SO     17.89
# Name: huml, Length: 420, dtype: float64

# %% [markdown]
# ## Print the "huml","humw" columns from SW and P

# %%
birds[["huml", "humw"]]
# Out:
#         huml   humw
# type
# SW     80.78   6.68
# SW     88.91   6.63
# SW     79.97   6.37
# SW     77.65   5.70
# SW     62.80   4.84
# SW     61.92   4.78
# SW     79.73   5.94
# SW     86.98   5.68
# SW    118.20   7.82
# SW    145.00  10.42
# SW    165.00  11.45
# SW    186.00   9.83
# SW    172.00   8.44
# SW    148.91   6.78
# SW    149.19   6.98
# SW    140.59   6.59
# SW    135.23   6.22
# SW    124.53   6.01
# SW    127.03   6.18
# SW    106.02   4.47
# SW    113.84   4.80
# SW    108.62   5.04
# SW    110.33   5.86
# SW     63.62   3.42
# SW     70.73   3.69
# SW     71.65   3.37
# SW     47.51   7.23
# SW     46.20   7.06
# SW     41.13   6.71
# SW     72.50  14.78
# ...      ...    ...
# SO     20.43   1.59
# SO     22.19   1.86
# SO     23.27   2.00
# SO     18.97   1.58
# SO     15.99   1.35
# SO     15.62   1.28
# SO     16.51   1.47
# SO     16.80   1.58
# SO     15.55   1.48
# SO     23.32   2.06
# SO     20.41   1.82
# SO     21.53   1.91
# SO     22.84   2.21
# ...

# %% [markdown]
# ## Select the rows 3 to 7 and the columns 3 to 6

# %%
print(birds.iloc[3:8][birds.columns[3:7]])
# Out:
#       ulnal  ulnaw   feml  femw
# type
# SW    65.76   4.77  40.04  3.52
# SW    52.09   3.73  33.95  2.72
# SW    50.46   3.47  49.52  4.41
# SW    67.39   4.50  42.07  3.41
# SW    74.52   4.55  44.46  3.78

# %% [markdown]
# ## Select rows where df.femw is greater than 5.2 or less than 10.5

# %%
birds[(birds["femw"] > 5.2) | (birds["femw"] < 10.5)]
# Out:
#        id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# type
# SW      0   80.78   6.68   72.01   4.88  41.81  3.70    5.50  4.03  38.70
# SW      1   88.91   6.63   80.53   5.59  47.04  4.30   80.22  4.51  41.50
# SW      2   79.97   6.37   69.26   5.28  43.07  3.90   75.35  4.04  38.31
# SW      3   77.65   5.70   65.76   4.77  40.04  3.52   69.17  3.40  35.78
# SW      4   62.80   4.84   52.09   3.73  33.95  2.72   56.27  2.96  31.88
# SW      5   61.92   4.78   50.46   3.47  49.52  4.41   56.95  2.73  29.07
# SW      6   79.73   5.94   67.39   4.50  42.07  3.41   71.26  3.56  37.22
# SW      7   86.98   5.68   74.52   4.55  44.46  3.78   76.02  3.81  37.94
# SW      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# SW      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# SW     10  165.00  11.45  156.00   8.68  80.25  7.85  143.00  8.25  86.61
# SW     11  186.00   9.83  152.00   8.76  56.02  7.02  185.00  8.07  90.80
# ...

# %% [markdown]
#  ## Select the third cell down in the column named tarl

# %%
print(birds["tarl"][2])
# Out:
# 38.31

# %% [markdown]
# ## Compute how many values are non-missing for each feature over the entire record.

# %%
print(birds.notnull().sum())
# Out:
# id       420
# huml     419
# humw     419
# ulnal    417
# ulnaw    418
# feml     418
# femw     419
# tibl     418
# tibw     419
# tarl     419
# tarw     419
# dtype: int64

# %% [markdown]
# ## Calculate Mean and Median of "tibl" and "tibw" columns

# %%
print("Mean")
print(birds[["tibl", "tibw"]].mean())
print("Median")
print(birds[["tibl", "tibw"]].median())
# Out:
# Mean
# tibl    64.662823
# tibw     3.182339
# dtype: float64
# Median
# tibl    52.12
# tibw     2.49
# dtype: float64

# %% [markdown]
# ## Discover what is the mean "ulnaw" per every bird category (use Groupby)

# %%
print(birds.groupby('ulnaw').mean())
# Out:
#                id        huml       humw       ulnal        feml       femw  \
# ulnaw
# 1.00   369.000000   13.480000   1.270000   16.000000   12.670000   1.100000
# 1.03   413.000000   12.950000   1.160000   14.090000   13.030000   1.030000
# 1.06   392.000000   14.186667   1.203333   16.736667   13.940000   1.030000
# 1.07   376.000000   13.520000   1.280000   17.880000   15.100000   1.050000
# 1.08   371.000000   13.670000   1.270000   17.520000   12.770000   1.160000
# 1.10   419.000000   17.890000   1.440000   19.260000   17.620000   1.340000
# 1.12   370.333333   15.353333   1.466667   19.170000   14.670000   1.056667
# 1.13   381.000000   15.615000   1.375000   18.345000   14.795000   1.120000
# 1.15   374.000000   14.880000   1.490000   19.550000   13.690000   0.980000
# 1.16   377.000000   12.690000   1.690000   17.440000   11.830000   1.030000
# 1.20   407.000000   15.700000   1.420000   18.580000   15.220000   1.080000
# ...

# %% [markdown]
# ## Plot graph between all features refuse "type" and "id" columns

# %%
import matplotlib.pyplot as plt

# %%
birds[['huml', 'humw', 'ulnal', 'feml', 'femw', 'tibl', 'tibw', 'tarl', 'tarw',]].plot(kind = 'hist')
